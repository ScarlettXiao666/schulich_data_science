# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 定义 x1 和 x2 的取值范围
x1 = np.linspace(-5, 5, 100)
x2 = np.linspace(-5, 5, 100)
x1, x2 = np.meshgrid(x1, x2)

# 计算 f(x) = x1^2 + x2^2
f = x1**2 + x2**2

# 创建三维图形
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制曲面
ax.plot_surface(x1, x2, f, cmap='viridis')

# 添加标签
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('f(x)')

# 设置标题
ax.set_title('$f(x) = x_1^2 + x_2^2$')

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 示例数据
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# 创建散点图
plt.scatter(x, y)
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Scatter Plot using Matplotlib')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 示例数据
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# 创建散点图
sns.scatterplot(x=x, y=y)
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Scatter Plot using Seaborn')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 生成示例数据
np.random.seed(0)
X1 = np.random.rand(100, 1) * 10  # 特征 1
X2 = np.random.rand(100, 1) * 10  # 特征 2
y = 3 + 2 * X1 + 1 * X2 + np.random.randn(100, 1)  # 目标值

# 拟合线性回归模型
from sklearn.linear_model import LinearRegression
model = LinearRegression()
X = np.hstack((X1, X2))
model.fit(X, y)
W0, W1, W2 = model.intercept_[0], model.coef_[0][0], model.coef_[0][1]

# 绘制数据点
plt.scatter(X1, X2, c=y, cmap='viridis', marker='o')
plt.xlabel('X1')
plt.ylabel('X2')

# 绘制线性回归模型的决策边界
x1_range = np.linspace(0, 10, 100)
x2_range = (W0 + W1 * x1_range) / (-W2)
plt.plot(x1_range, x2_range, color='red', linewidth=2, label=f'{W1:.2f}X1 + {W2:.2f}X2 + {W0:.2f} = 0')

plt.legend()
plt.colorbar(label='y')
plt.title('Linear Regression Model')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

# 生成训练数据
X_train = np.array([1500, 2000, 2500, 3000, 3500]).reshape(-1, 1)
y_train = np.array([300, 400, 500, 600, 700])

# 生成测试数据
X_test = np.linspace(1000, 4000, 100).reshape(-1, 1)

# 简单模型
model_simple = LinearRegression()
model_simple.fit(X_train, y_train)
y_pred_simple = model_simple.predict(X_test)

# 复杂模型（高次多项式）
model_complex = make_pipeline(PolynomialFeatures(degree=10), LinearRegression())
model_complex.fit(X_train, y_train)
y_pred_complex = model_complex.predict(X_test)

# 绘图
plt.scatter(X_train, y_train, color='blue', label='Training data')
plt.plot(X_test, y_pred_simple, color='green', label='Simple model')
plt.plot(X_test, y_pred_complex, color='red', label='Complex model')
plt.xlabel('Area (sq ft)')
plt.ylabel('Price (thousand dollars)')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

# 生成样本数据
np.random.seed(0)
x = np.sort(np.random.rand(100))
y = 1.5 * x**2 - 0.5 * x + 2 + 0.1 * np.random.randn(100)

# 构建多项式回归模型
degree = 2
model = make_pipeline(PolynomialFeatures(degree), LinearRegression())
model.fit(x.reshape(-1, 1), y)

# 生成预测值
x_test = np.linspace(0, 1, 100)
y_pred = model.predict(x_test.reshape(-1, 1))

# 绘制结果
plt.scatter(x, y, color='blue', label='Training data')
plt.plot(x_test, y_pred, color='red', label='Polynomial regression (degree=2)')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title('Polynomial Regression Example')
plt.show()
